# %% [markdown]
# <a href="https://colab.research.google.com/github/varunasnv7-cpu/Varun_Info_5731_Spring2026/blob/main/In_class_exercises_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **In-Class Assignment — Week 2 (Lesson 2)**
#
# Time: 20–30 minutes
# Points: 10
#
# **Instructions**
#
# This is an individual in-class assignment.
#
# Complete it during class time.
#
# You may use Week 2 lecture notes / demo notebooks.
#
# Write your code under each question and print the output.
#
# Submit the GitHub link.

# %% [markdown]
# ## Question 1 ( 2 point)
# Write a Python program that  prompts the user to input the length and width of a rectangle, and then calculates and displays the area of the rectangle.

# %%
print("Rectangle Area Calculator")

length = float(input("Enter length: "))
width = float(input("Enter width: "))

area = length * width
print("Area:", area)
# Out:
# Rectangle Area Calculator
# Enter length: 6
# Enter width: 4
# Area: 24.0

# %% [markdown]
# ## Question 2 ( 2 point)
# Create a Python program that interactively takes two numerical inputs from the user and swaps their values without utilizing an extra variable.

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))


print("Before swapping:")
print("a =", a)
print("b =", b)


a, b = b, a


print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number: 5
# Enter second number: 7
# Before swapping:
# a = 5.0
# b = 7.0
# After swapping:
# a = 7.0
# b = 5.0

# %% [markdown]
# ## Question 3 ( 2 point)
# Write a Python script to determine and print the length of a user-input string.

# %%
user_string = input("Enter a string: ")


length = len(user_string)

print("The length of the string is:", length)
# Out:
# Enter a string: Varun
# The length of the string is: 5

# %% [markdown]
# ## Question 4 ( 2 point)
# Design a Python function to check if a number is prime.

# %%
num = int(input("Enter a number: "))

if is_prime(num):
    print(num, "is a prime number")
else:
    print(num, "is not a prime number")
# Out:
# Enter a number: 3
# 3 is a prime number

# %% [markdown]
# ## Question 5 ( 2 point)
# Write a Python program to concatenate following dictionaries to create a new one.
#
# Sample Dictionary : dic1={1:10, 2:20}, dic2={3:30, 4:40}, dic3={5:50,6:60},
#
# Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
dic1 = {1:10, 2:20}
dic2 = {3:30, 4:40}
dic3 = {5:50, 6:60}

result = {}
result.update(dic1)
result.update(dic2)
result.update(dic3)

print(result)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
